# %%
import pandas as pd

# %%
data1=pd.read_csv("account_profile_1.csv")

# %%
data2=pd.read_csv("DQmaster.csv",encoding= 'unicode_escape')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,7,11,12,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data1.head()
data1.columns.sort_values
data1.shape
# Out:
# (623, 24)

# %%
data2.head()
# Out:
#         DQ_NO ACCT_NO TRAN_CODE NETW_CARR     MAST_NO  DEPT_NO  SEQU_NO  \
# 0  1304734489     NaN         I       HCL  1510000001        0       10
# 1  1304734490     NaN         I       HCL  1510000228        0        1
# 2  1304734493     NaN         I       HCL  1510000448        0        1
# 3  1304734494     NaN         I       HCL  1510000448        0        2
# 4  1304734497     NaN         I       HCL  1510000519        0        1
#
#     PHON_NO                 ENGL_CUST_NAME ENGL_CAP1  ... COMM_TYPE DISP_INDC  \
# 0  28100772  Hutchison Whampoa (China) Ltd       Fax  ...         V         N
# 1  25440899       Data Asia Technology Ltd       NaN  ...         V         N
# 2  21281188          Hutchison Whampoa Ltd       NaN  ...         V         N
# 3  21281705          Hutchison Whampoa Ltd       Fax  ...         V         N
# 4  28381812         Modern China Trade Ltd       NaN  ...         V         N
#
# ...

# %%
data2.columns.sort_values()
# Out:
# Index(['ACCT_NO', 'CHIN_ADDR', 'CHIN_CAP1', 'CHIN_CAP2', 'CHIN_CAP3',
#        'CHIN_CAP4', 'CHIN_CUST_NAME', 'COMM_TYPE', 'DEPT_NO', 'DISP_INDC',
#        'DIST_CODE', 'DQ_NO', 'DUMMY_ADDR', 'DUMMY_NAME', 'ENGL_ADDR',
#        'ENGL_CAP1', 'ENGL_CAP2', 'ENGL_CAP3', 'ENGL_CAP4', 'ENGL_CUST_NAME',
#        'FREQUENCE', 'LAST_UPDT_DATE', 'LAST_UPDT_USER', 'MAST_NO', 'NETW_CARR',
#        'PHON_NO', 'PRINT_YN', 'SEQU_NO', 'TARI_CODE', 'TRAN_CODE', 'TRAN_TIME',
#        'YELLOW_PAGE_YN'],
#       dtype='object')

# %%
save=data1[data1['LINE_NO'].notnull()]

# %%
data1.shape
# Out:
# (623, 24)

# %%
lineno=list(data1['LINE_NO'])

# %%
data2
# Out:
#              DQ_NO ACCT_NO TRAN_CODE NETW_CARR     MAST_NO  DEPT_NO  SEQU_NO  \
# 0       1304734489     NaN         I       HCL  1510000001        0       10
# 1       1304734490     NaN         I       HCL  1510000228        0        1
# 2       1304734493     NaN         I       HCL  1510000448        0        1
# 3       1304734494     NaN         I       HCL  1510000448        0        2
# 4       1304734497     NaN         I       HCL  1510000519        0        1
# ...            ...     ...       ...       ...         ...      ...      ...
# 692397  1305459356     NaN         I       HKT  1003863698        2    33333
# 692398  1305459357     NaN         I       HKT  1003863698        2    66666
# 692399  1305459358     NaN         I       HKT  1003880708        0   200100
# 692400  1305459359     NaN         I       HKT  1003880708        0   200200
# 692401  1305459360     NaN         I       HKT  1003880708        0   200300
#
# ...

# %%
ans=list(data2['PHON_NO'][data2['PHON_NO'].isin(lineno)])

save_customer=list(data2['ENGL_CUST_NAME'][data2['PHON_NO'].isin(lineno)])
data2[data2['PHON_NO'].isin(lineno)]
# Out:
#              DQ_NO ACCT_NO TRAN_CODE NETW_CARR     MAST_NO  DEPT_NO  SEQU_NO  \
# 0       1304734489     NaN         I       HCL  1510000001        0       10
# 23      1304734518     NaN         I       HCL  1510001030        0        1
# 28      1304734524     NaN         I       HCL  1510001075        0        1
# 353     1304734817     NaN         I       HCL  1510003333        0        1
# 401     1304734866     NaN         I       HCL  1510003736        0        1
# 1657    1304736296     NaN         I       HCL  1510013704        0       10
# 1658    1304736297     NaN         I       HCL  1510013704       10       20
# 22445   1304759870     NaN         I       HCL  1510154869        0        1
# 92631   1304832464     NaN         I       HCL  1510397580       10       11
# 92632   1304832465     NaN         I       HCL  1510397580       20       21
# 92633   1304832466     NaN         I       HCL  1510397580       30       31
# ...

# %%
finaldata1=list(data1['CUST_NAME'][data1['LINE_NO'].isin(ans)])

# %%
finaldata1=finaldata1[:-2]
finaldata1
# Out:
# ['HUTCHISON WHAMPOA (CHINA) LTD',
#  'HUTCHISON WHAMPOA (CHINA) LTD',
#  'HUTCHISON WHAMPOA (CHINA) LTD',
#  'HUTCHISON WHAMPOA (CHINA) LTD',
#  'HUTCHISON WHAMPOA (CHINA) LTD',
#  'HUTCHISON WHAMPOA (CHINA) LTD',
#  'HUTCHISON WHAMPOA (CHINA) LTD',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS',
#  'FORTRESS']

# %%
len(save_customer)
save_customer
# Out:
# ['Hutchison Whampoa (China) Ltd',
#  'Fortress',
#  'Fortress Ltd The',
#  'Fortress',
#  'Fortress',
#  'Fortress',
#  'Fortress',
#  'Winner Fortune Ltd',
#  'Prime Consulting Engineers Ltd',
#  'Prime Consulting Engineers Ltd',
#  'Prime Consulting Engineers Ltd',
#  'Aces Internatl (HK) Ltd',
#  'Zzue Creation',
#  'GDC Technology Ltd',
#  'Overseas Employment Centre Ltd',
#  'Overseas Employment Centre Ltd',
#  'Kasikornbank Public Co Ltd',
#  'Citic Internatl Assets Mgt Ltd',
#  'IDP Education Ltd',
#  'Belle Internatl (China) Ltd',
#  'Eaglehigh Mgt Ltd',
#  'Fortress-A Division Of AS Watson Group (HK) Ltd',
#  'Lam Mei Wa',
#  'Md Medical Servs Ltd',
#  'Fortress',
#  'Fortress',
#  'Fortress',
#  'Fortress',
#  'FWD Life Ins Co (Bermuda) Ltd',
#  'Linkup Business Servs Ltd']

# %%
conda install -c conda-forge fuzzywuzzy
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from fuzzywuzzy import fuzz

# %%
save_val=[]
for i in range(len(save_customer)):

    Ratio = fuzz.ratio(save_customer[i].lower(),finaldata[i].lower())
    save_val.append(Ratio)

# %%
task=pd.DataFrame(save_customer,columns=['customer1'])

# %%
task['customer2']=finaldata1

# %%
task['Ratio']=save_val

# %%
task.to_csv("task.csv")
