# %%
import pandas as pd
import numpy as np

# %%
data2=pd.read_csv("dqmaster_refined.csv")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data1=pd.read_csv("acc_refined.csv")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (8,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data1.columns
data1.shape
data1.head()
data1['LINE_NO']=data1['LINE_NO'].astype(str)

# %%
data2.columns
data2.shape
data2['LINE_NO']=data2['LINE_NO'].astype(str)
data2.head()
# Out:
#    Unnamed: 0       DQ_NO NETW_CARR     MAST_NO  DEPT_NO   LINE_NO  \
# 0           0  1304734489       HCL  1510000001        0  28100772
# 1           1  1304734490       HCL  1510000228        0  25440899
# 2           2  1304734493       HCL  1510000448        0  21281188
# 3           3  1304734494       HCL  1510000448        0  21281705
# 4           4  1304734497       HCL  1510000519        0  28381812
#
#                   ENGL_CUST_NAME ENGL_CAP1 ENGL_CAP2 ENGL_CAP3 ENGL_CAP4  \
# 0  Hutchison Whampoa (China) Ltd       Fax       NaN       NaN       NaN
# 1       Data Asia Technology Ltd       NaN       NaN       NaN       NaN
# 2          Hutchison Whampoa Ltd       NaN       NaN       NaN       NaN
# 3          Hutchison Whampoa Ltd       Fax       NaN       NaN       NaN
# 4         Modern China Trade Ltd       NaN       NaN       NaN       NaN
#
#             ENGL_ADDR  DIST_CODE
# 0       Hutchison Hse        105
# 1  Xiu Ping Coml Bldg        104
# 2       Hutchison Hse        105
# 3       Hutchison Hse        105
# 4    Eastern Coml Ctr        106

# %%
data1['CUST_NAME']=data1['CUST_NAME'].str.lower()
data2['ENGL_CUST_NAME']=data2['ENGL_CUST_NAME'].str.lower()

# %%
data_cust_acc=list(data1['CUST_NAME'].unique())

# %%
ans=data2.copy().head(100)
ans.to_csv("test.csv")

# %%
preprocess=pd.read_csv("Preprocess.csv")

# %%
preprocess.head()
# Out:
#                                            CUST_NAME ENGL_CUST_NAME
# 0  <Replace ',' and '.' with ' ' and replace doub...            NaN
# 1                                     INTERNATIONAL      Internatl
# 2                                             INT'L      Internatl
# 3                                           TRADING           Trdg
# 4                                            LIMITED            Ltd

# %%
preprocess['CUST_NAME']=preprocess['CUST_NAME'].str.lower()

# %%
preprocess['ENGL_CUST_NAME']=preprocess['ENGL_CUST_NAME'].str.lower()

# %%
preprocess.head()
# Out:
#                                            CUST_NAME ENGL_CUST_NAME
# 0  <replace ',' and '.' with ' ' and replace doub...            NaN
# 1                                     international      internatl
# 2                                             int'l      internatl
# 3                                           trading           trdg
# 4                                            limited            ltd

# %%
preprocess=preprocess.drop(index=0)

# %%
mydict = dict(zip(preprocess.ENGL_CUST_NAME, preprocess.CUST_NAME))
mydict
# Out:
# {' internatl ': " int'l ",
#  ' trdg ': ' trading ',
#  ' ltd': ' limited',
#  ' co': ' company',
#  ' rest': ' restaurant',
#  ' rests': ' restaurants',
#  ' hse': ' house',
#  ' advtg ': ' advertising ',
#  ' furn': ' furniture',
#  ' agcy': ' agency',
#  ' warehse': ' warehouse',
#  ' transp ': ' transportation ',
#  ' serv': ' service',
#  ' servs': ' services',
#  ' (hk) ': ' (hong kong) ',
#  'hk': 'hong kong',
#  ' assn': ' association',
#  ' engrg': ' engineering',
#  ' prods ': ' products ',
#  ' prod ': ' product ',
#  ' corp': ' corporation',
#  ' prtg': ' printing',
#  ' ind ': ' industrial ',
#  ' mfg': ' manufacturing'}

# %%
# data_cust_dq=list(ans['ENGL_CUST_NAME'])
val=list(ans['ENGL_CUST_NAME'])

# %%
conda install -c conda-forge fuzzywuzzy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from fuzzywuzzy import fuzz

# %%
from tqdm import tqdm
save_ratio=[]
save_cust=[]
final_ratio=[]
final_cust=[]
count=0
save_both=[]
for i in tqdm(range(len(val))):
    save_ratio=[]
    save_cust=[]
    save_both=[]
    for j in data_cust_acc:
#         print(val[i],j)
        Ratio = fuzz.token_sort_ratio(val[i],j)

        
        if Ratio>=80:
            inter_save=str(Ratio)+"|"+j
#             print(inter_save)
            new_save=list(inter_save.split("|"))
#             print(new_save)
#             save_ratio.append(Ratio)
#             save_cust.append(j)
            save_both.append(new_save)
#             count+=1
#             valcheck=max(int(save_both[]))
#             print(valcheck)
        
    if save_both==[]:
        final_ratio.append(None)
        final_cust.append(None)
    elif len(save_both)>0:
        
        
        valnext1=[int(row[0]) for row in save_both]
#         print(valnext1)
        save=valnext1.index(max(valnext1))
#         print(save)
        ans1=save_both[save]
    
        final_ratio.append(ans1[0])
        final_cust.append(ans1[1])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#   1%|          | 1/100 [00:04<07:32,  4.58s/it]
#
#
#
#
#
#
#
#
#
#
#   2%|▏         | 2/100 [00:09<07:33,  4.63s/it]
#
#
#
#
#
#
#
#
#
#
#   3%|▎         | 3/100 [00:13<07:24,  4.59s/it]
#
#
#
#
#
#
#
#
#
#
#   4%|▍         | 4/100 [00:18<07:13,  4.52s/it]
#
#
#
#
#
#
#
#
#
#
#   5%|▌         | 5/100 [00:22<07:07,  4.50s/it]
#
#
#
#
#
#
#
#
#
#
#   6%|▌         | 6/100 [00:27<07:01,  4.48s/it]
#
#
#
#
#
#
#
#
#
#
#   7%|▋         | 7/100 [00:31<07:06,  4.59s/it]
#
#
#
#
#
#
#
#
#
#
#   8%|▊         | 8/100 [00:37<07:30,  4.90s/it]
#
#
#
#
#
#
#
#
#
#
#   9%|▉         | 9/100 [00:42<07:22,  4.86s/it]
#
#
#
#
#
#
#
#
#
#
#  10%|█         | 10/100 [00:48<07:59,  5.32s/it]
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 11/100 [00:53<07:31,  5.07s/it]
#
#
#
#
#
#
#
#
#
#
#  12%|█▏        | 12/100 [00:57<07:12,  4.92s/it]
#
#
#
#
#
#
#
#
#
#
#  13%|█▎        | 13/100 [01:01<06:46,  4.67s/it]
#
#
#
#
#
#
#
#
#
#
#  14%|█▍        | 14/100 [01:06<06:28,  4.52s/it]
#
#
#
#
#
#
#
#
#
#
#  15%|█▌        | 15/100 [01:10<06:18,  4.46s/it]
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 16/100 [01:14<06:03,  4.33s/it]
#
#
#
#
#
#
#
#
#
#
#  17%|█▋        | 17/100 [01:18<05:55,  4.28s/it]
#
#
#
#
#
#
#
#
#
#
#  18%|█▊        | 18/100 [01:22<05:46,  4.22s/it]
#
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 19/100 [01:27<05:51,  4.34s/it]
#
#
#
#
#
#
#
#
#
#
#  20%|██        | 20/100 [01:31<05:42,  4.28s/it]
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 21/100 [01:36<06:04,  4.62s/it]
#
#
#
#
#
#
#
#
#
#
#  22%|██▏       | 22/100 [01:41<06:11,  4.77s/it]
#
#
#
#
#
#
#
#
#
#
#  23%|██▎       | 23/100 [01:47<06:26,  5.02s/it]
#
#
#
#
#
#
#
#
#
#
#  24%|██▍       | 24/100 [01:51<06:07,  4.83s/it]
#
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 25/100 [01:57<06:12,  4.97s/it]
#
#
#
#
#
#
#
#
#
#
#  26%|██▌       | 26/100 [02:01<05:57,  4.82s/it]
#
#
#
#
#
#
#
#
#
#
#  27%|██▋       | 27/100 [02:05<05:32,  4.55s/it]
#
#
#
#
#
#
#
#
#
#
#  28%|██▊       | 28/100 [02:10<05:26,  4.54s/it]
#
#
#
#
#
#
#
#
#
#
#  29%|██▉       | 29/100 [02:14<05:10,  4.37s/it]
#
#
#
#
#
#
#
#
#
#
#  30%|███       | 30/100 [02:18<05:09,  4.43s/it]
#
#
#
#
#
#
#
#
#
#
#  31%|███       | 31/100 [02:22<05:02,  4.38s/it]
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 32/100 [02:27<04:54,  4.34s/it]
#
#
#
#
#
#
#
#
#
#
#  33%|███▎      | 33/100 [02:31<04:55,  4.40s/it]
#
#
#
#
#
#
#
#
#
#
#  34%|███▍      |
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▌| 95/100 [07:05<00:24,  4.88s/it]
#
#
#
#
#
#
#
#
#
#
#  96%|█████████▌| 96/100 [07:11<00:19,  4.97s/it]
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 97/100 [07:16<00:15,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#  98%|█████████▊| 98/100 [07:21<00:10,  5.01s/it]
#
#
#
#
#
#
#
#
#
#
#  99%|█████████▉| 99/100 [07:25<00:04,  4.75s/it]
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 100/100 [07:29<00:00,  4.50s/it]

# %%
print(final_ratio)
# Out:
# ['100']

# %%
print(final_cust)
# Out:
# ['hutchison whampoa (china) ltd.']

# %%
valnext1=[int(row[0]) for row in valnext]
save=valnext1.index(max(valnext1))

ans1=valnext[save]
ans1[0]
ans1[1]
# Out:
# 'hutchison whampoa (china) ltd.'

# %%
ans['Names']=final_cust
ans['Ratios']=final_ratio

# %%
ans
# Out:
#     Unnamed: 0       DQ_NO NETW_CARR     MAST_NO  DEPT_NO   LINE_NO  \
# 0            0  1304734489       HCL  1510000001        0  28100772
# 1            1  1304734490       HCL  1510000228        0  25440899
# 2            2  1304734493       HCL  1510000448        0  21281188
# 3            3  1304734494       HCL  1510000448        0  21281705
# 4            4  1304734497       HCL  1510000519        0  28381812
# ..         ...         ...       ...         ...      ...       ...
# 95          95  1304734547       HCL  1510001301        3  27648589
# 96          96  1304734548       HCL  1510001322        0  21218080
# 97          97  1304734549       HCL  1510001322        0  31634530
# 98          98  1304734550       HCL  1510001322        0  21218621
# 99          99  1304734551       HCL  1510001322        1  21218628
#
#                    ENGL_CUST_NAME                    ENGL_CAP1  \
# 0   hutchison whampoa (china) ltd                          Fax
# 1        data asia technology ltd                          NaN
# 2           hutchison whampoa ltd                          NaN
# 3           hutchison whampoa ltd                          Fax
# 4          modern china trade ltd                          NaN
# ..                            ...                          ...
# 95                sui fung hk ltd                          NaN
# 96           department of health      24 Hours Health Hotline
# 97           department of health   Lam Tin Schl Dental Clinic
# 98           department of health      Elderly Health Services
# 99           department of health  Elderly Health Servs ( HQ )
#
#                ENGL_CAP2 ENGL_CAP3 ENGL_CAP4                      ENGL_ADDR  \
# 0                    NaN       NaN       NaN                  Hutchison Hse
# 1                    NaN       NaN       NaN             Xiu Ping Coml Bldg
# 2                    NaN       NaN       NaN                  Hutchison Hse
# 3                    NaN       NaN       NaN                  Hutchison Hse
# 4                    NaN       NaN       NaN               Eastern Coml Ctr
# ..                   ...       ...       ...                            ...
# 95                   NaN       NaN       NaN                    Winner Bldg
# 96  Elderly Health Servs       NaN       NaN                       Wan Chai
# 97                   Fax       NaN       NaN  Lam Tn Poly Clinic Kai Tin Rd
# 98      Public Enquiries       NaN       NaN                Hopewell Centre
# 99                   Fax       NaN       NaN                       Wan Chai
#
#     DIST_CODE                           Names Ratios
# 0         105  hutchison whampoa (china) ltd.    100
# 1         104        data asia technology ltd    100
# 2         105           hutchison whampoa ltd    100
# 3         105           hutchison whampoa ltd    100
# 4         106          open trade (china) ltd     90
# ..        ...                             ...    ...
# 95         11           sui fung (hk) limited     88
# 96        106            department of health    100
# 97         28            department of health    100
# 98        106            department of health    100
# 99        106            department of health    100
#
# [100 rows x 15 columns]
