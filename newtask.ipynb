# %%
import pandas as pd

# %%
data2=pd.read_csv("dqmaster_refined.csv")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data1=pd.read_csv("acc_refined.csv")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (8,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data1.columns
data1.shape
data1.head()
data1['LINE_NO']=data1['LINE_NO'].astype(str)

# %%
data2.columns
data2.shape
data2['LINE_NO']=data2['LINE_NO'].astype(str)

# %%
new_data2=data2[['LINE_NO','DQ_NO','ENGL_CUST_NAME']]
new_data2['LINE_NO']=new_data2['LINE_NO'].astype(str)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ans = pd.merge(data1, new_data2, on=['LINE_NO'], how='inner')
ans['LINE_NO']=ans['LINE_NO'].astype(str)
ans.head()
ans.to_csv("output.csv")

# %%
newdata=pd.read_csv("output.csv")
newdata['LINE_NO']=newdata['LINE_NO'].astype(str)
newdata.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  Unnamed: 0.1 SYSTEM CATG_MGT_PNL ACCT_CATG  \
# 0           0             6   ONOP         BDEL         B
# 1           1       1043551   ONOP          NaN         C
# 2           2             7   ONOP         BDEL         B
# 3           3            13   ONOP         BDEL         B
# 4           4            18   ONOP          NaN         B
#
#                               CUST_NAME                             ACCT_NAME  \
# 0     LEE KWAN KNITWEAR UNIFORM COMPANY     LEE KWAN KNITWEAR UNIFORM COMPANY
# 1                   DEVI TRADING CO LTD                   DEVI TRADING CO LTD
# 2                          OBSO21168976                          OBSO21168976
# ...

# %%
conda install -c conda-forge fuzzywuzzy
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from fuzzywuzzy import fuzz

# %%
save_val=[]

val1=list(newdata['CUST_NAME'])
val2=list(newdata['ENGL_CUST_NAME'])

for i in range(len(val1)):

    Ratio = fuzz.token_sort_ratio(val1[i].lower(),val2[i].lower())
    save_val.append(Ratio)

# %%
newdata['Ratio']=save_val

# %%
newdata
# Out:
#         Unnamed: 0  Unnamed: 0.1 SYSTEM CATG_MGT_PNL ACCT_CATG  \
# 0                0             6   ONOP         BDEL         B
# 1                1       1043551   ONOP          NaN         C
# 2                2             7   ONOP         BDEL         B
# 3                3            13   ONOP         BDEL         B
# 4                4            18   ONOP          NaN         B
# ...            ...           ...    ...          ...       ...
# 154153      154153       2880347   ONOP          NaN        ME
# 154154      154154       2880411   ONOP          NaN         B
# 154155      154155       2880443   ONOP          NaN         B
# 154156      154156       2880449   ONOP          NaN         B
# 154157      154157       2880462   ONOP         BDEL         B
#
#                                    CUST_NAME  \
# 0          LEE KWAN KNITWEAR UNIFORM COMPANY
# 1                        DEVI TRADING CO LTD
# 2                               OBSO21168976
# ...

# %%
newdata.to_csv("finaloutput.csv")

# %%
data2[data2['LINE_NO']=='28100772']
# Out:
#    Unnamed: 0       DQ_NO NETW_CARR     MAST_NO  DEPT_NO   LINE_NO  \
# 0           0  1304734489       HCL  1510000001        0  28100772
#
#                   ENGL_CUST_NAME ENGL_CAP1 ENGL_CAP2 ENGL_CAP3 ENGL_CAP4  \
# 0  Hutchison Whampoa (China) Ltd       Fax       NaN       NaN       NaN
#
#        ENGL_ADDR  DIST_CODE
# 0  Hutchison Hse        105
